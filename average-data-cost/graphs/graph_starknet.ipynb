# %%
import matplotlib.pyplot as plt
import json
import numpy as np
import matplotlib
from matplotlib.pyplot import figure
matplotlib.rcParams['text.usetex'] = True
plt.style.use('science')

#load starknet gas data
with open("../data/starknet215.json", "r") as f:
    data = json.load(f)

#(blockNumber) -> [eth_timestamp, tx_count, blockGasConsumed]
x_ts = []
y_txs = []
y_gas = []

for ts in data:
    x_ts.append(ts)
    y_txs.append(data[ts][1])
    y_gas.append(data[ts][2]/data[ts][1])


y_gas_mean = [np.mean(y_gas)] * len(y_gas)

print("Summary Statistics (Gas)")
print("Mean:", np.mean(y_gas))
print("Standard Deviation:", np.std(y_gas))
print("Correlation:", np.corrcoef(y_txs, y_gas)[0][1]) #even with fluctuating ETH price, high correlation

fig,ax = plt.subplots(figsize=(18.5, 10.5), dpi=80)

# Plot the data
data_line = ax.plot(x_ts , y_gas, label='Transaction Cost')

# Plot the average line
mean_line = ax.plot(x_ts,y_gas_mean, label='Mean', linestyle='--')

# Make a legend
legend = ax.legend(loc='upper right', fontsize=20, facecolor = "black")

plt.title("Starknet - Average Gas Used in Sequencer Block", fontsize = 20)
plt.xlabel("Starknet Block Number (block)", fontsize=16)
plt.ylabel("Gas Used (gas)", fontsize=16)

ax.xaxis.set_major_locator(plt.MaxNLocator(10))
        
plt.show()
# Out:
# Summary Statistics (Gas)
# Mean: 5178.745405245563
# Standard Deviation: 1211.5561151729848
# Correlation: -0.7051026337889805
